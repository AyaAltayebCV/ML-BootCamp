# %% [markdown]
# Assignment_01

# %%
#Question_01
import numpy as np
import pandas as pd
print(np.__version__)
# Out:
# 1.21.6

# %%
#Question_02:
df = pd.read_csv('./data.csv')
df.shape
# Out:
# (11914, 16)

# %%
#Question_03]
df.groupby('Make')['Make'].value_counts().nlargest(5)
# Out:
# Make        Make
# Chevrolet   Chevrolet     1123
# Ford        Ford           881
# Volkswagen  Volkswagen     809
# Toyota      Toyota         746
# Dodge       Dodge          626
# Name: Make, dtype: int64

# %%
#Question_04
models = df.loc[df['Make'] == 'Audi']['Model'].unique()
len(models)
# Out:
# 34

# %%
#Question_05
nulls = df.isnull().sum().apply(lambda x: x>0)
nulls.sum()
# Out:
# 5
